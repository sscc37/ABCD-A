# %% [markdown]
# <a href="https://colab.research.google.com/github/sscc37/ABCD-A/blob/20250331/python0331.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x1 = float(input("첫 번째 벡터의 x 성분을 입력하세요: "))
y1 = float(input("첫 번째 벡터의 y 성분을 입력하세요: "))
z1 = float(input("첫 번째 벡터의 z 성분을 입력하세요: "))

x2 = float(input("두 번째 벡터의 x 성분을 입력하세요: "))
y2 = float(input("두 번째 벡터의 y 성분을 입력하세요: "))
z2 = float(input("두 번째 벡터의 z 성분을 입력하세요: "))

sum_x = x1 + x2
sum_y = y1 + y2
sum_z = z1 + z2

dot_product = x1 * x2 + y1 * y2 + z1 * z2

cross_x = y1 * z2 - z1 * y2
cross_y = z1 * x2 - x1 * z2
cross_z = x1 * y2 - y1 * x2

print("\n벡터 1:", x1, "i +", y1, "j +", z1, "k")
print("벡터 2:", x2, "i +", y2, "j +", z2, "k")
print("\n벡터의 합:", sum_x, "i +", sum_y, "j +", sum_z, "k")
print("벡터의 내적:", dot_product)
print("벡터의 외적:", cross_x, "i +", cross_y, "j +", cross_z, "k")
# Out:
# 첫 번째 벡터의 x 성분을 입력하세요: 6
# 첫 번째 벡터의 y 성분을 입력하세요: 7
# 첫 번째 벡터의 z 성분을 입력하세요: 8
# 두 번째 벡터의 x 성분을 입력하세요: 9
# 두 번째 벡터의 y 성분을 입력하세요: 10
# 두 번째 벡터의 z 성분을 입력하세요: 11
#
# 벡터 1: 6.0 i + 7.0 j + 8.0 k
# 벡터 2: 9.0 i + 10.0 j + 11.0 k
#
# 벡터의 합: 15.0 i + 17.0 j + 19.0 k
# 벡터의 내적: 212.0
# 벡터의 외적: -3.0 i + 6.0 j + -3.0 k

# %%
x1 = float(input("첫 번째 벡터의 x 성분을 입력하세요: "))
y1 = float(input("첫 번째 벡터의 y 성분을 입력하세요: "))

x2 = float(input("두 번째 벡터의 x 성분을 입력하세요: "))
y2 = float(input("두 번째 벡터의 y 성분을 입력하세요: "))

sum_x = x1 + x2
sum_y = y1 + y2

dot_product = x1 * x2 + y1 * y2

cross_product = x1 * y2 - y1 * x2

print("\n벡터 1:", x1, "i +", y1, "j")
print("벡터 2:", x2, "i +", y2, "j")

print("\n벡터의 합:", sum_x, "i +", sum_y, "j")
print("벡터의 내적:", dot_product)
print("벡터의 외적:", cross_product)
# Out:
# 첫 번째 벡터의 x 성분을 입력하세요: 6
# 첫 번째 벡터의 y 성분을 입력하세요: 7
# 두 번째 벡터의 x 성분을 입력하세요: 8
# 두 번째 벡터의 y 성분을 입력하세요: 9
#
# 벡터 1: 6.0 i + 7.0 j
# 벡터 2: 8.0 i + 9.0 j
#
# 벡터의 합: 14.0 i + 16.0 j
# 벡터의 내적: 111.0
# 벡터의 외적: -2.0
