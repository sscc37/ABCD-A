# %% [markdown]
# <a href="https://colab.research.google.com/github/sscc37/ABCD-A/blob/20250320/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
int(5 / 2)
# Out:
# 2

# %%
5 // 2
# Out:
# 2

# %%
a = 1024
print(a)


a += 1024
a
# Out:
# 1024
# 2048

# %%
a=4
b=3

c=1
d=2
print(a/b)
print(c/d)

e=7
f=3
print(e//f)
print(e&f)

print(e**f)
# Out:
# 1.3333333333333333
# 0.5
# 2
# 3
# 343

# %%
divmod(5,2)
# Out:
# (2, 1)

# %%
a=11+2
b=12-2
c=13*2
d=14/2
e=15**2
f=16//2
g=17%3
print(a,b,c,d,e,f,g)
# Out:
# 13 10 26 7.0 225 8 2

# %%
a=10
a **= 2
print(a)
# Out:
# 100

# %%
i=3
i+=3
print(i)

i*=2
print(i)

i/=2
print(int(i))
i=3
i&=2
print(i)
# Out:
# 6
# 12
# 6
# 2

# %%
a=10
b=3
print("10==3=>",a==b)
print("10!=3=>",a!=b)
a=10
b=3
print("10==3=>",a==b)
print("10!=3=>",a!=b)
print("10>3=>",a>b)
print("10>=3=>",a>=b)
print("10<3=>",a<b)
print("10<=3=>",a<=b)
print()
# Out:
# 10==3=> False
# 10!=3=> True
# 10==3=> False
# 10!=3=> True
# 10>3=> True
# 10>=3=> True
# 10<3=> False
# 10<=3=> False

# %%
bin(13)
# Out:
# '0b1101'

# %%
0b1101
# Out:
# 13

# %%
int('1101',2)
# Out:
# 13

# %%
a=13
print(bin(a))
print(hex(a))
# Out:
# 0b1101
# 0xd

# %%
bin(0b1101&0b101)
13&9
# Out:
# 9

# %%
bin(0b1101|0b101)
13|9
# Out:
# 13

# %%
bin(0b1101^0b101)
13^9
# Out:
# 4

# %%
bin(~0b1101)
~13
# Out:
# -14

# %%
a=13
b=9
print(bin(a))
print(bin(b))
print('')
print(bin(a&b))
print(a&b)

print(bin(a))
print(bin(b))
print('')
print(bin(a|b))
print(a|b)

print('')
print(bin(a))
print(bin(b))
print(bin(a^b))
print('')
print(a^b)

print('')
print(bin(a))
print(bin(~a))
# Out:
# 0b1101
# 0b1001
#
# 0b1001
# 9
# 0b1101
# 0b1001
#
# 0b1101
# 13
#
# 0b1101
# 0b1001
# 0b100
#
# 4
#
# 0b1101
# -0b1110
